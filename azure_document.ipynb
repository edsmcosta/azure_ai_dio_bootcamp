# %% [markdown]
# # Azure Document (Colab-ready)
#
# This notebook was initialized for Google Colab.
#
# Open this notebook in Colab via *File → Open notebook → GitHub* or use the Colab badge if present.

# %%
# Example starter cell
print('Hello, Colab!')
